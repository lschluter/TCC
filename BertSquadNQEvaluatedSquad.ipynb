# %% [markdown]
# <a href="https://colab.research.google.com/github/lschluter/TCC/blob/develop/BertSquadNQEvaluatedSquad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install datasets

# %%
pip install transformers

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from transformers import pipeline
import datasets
import numpy as np

# Load the SQuAD v1.1 dataset
squad_dataset = datasets.load_dataset("squad")

# Load the question answering pipeline with the "bert-base-uncased" model
qa_pipeline = pipeline("question-answering", model="leonardoschluter/bert-base-uncased-finetuned-squad-finetuned-nq", tokenizer="leonardoschluter/bert-base-uncased-finetuned-squad-finetuned-nq")

# Initialize variables to store evaluation results
total_exact_match = 0
total_f1_score = 0
total_examples = len(squad_dataset["validation"])

# %%
import datetime
# Loop through the validation dataset
iterator = 0
e = datetime.datetime.now()
print("%s" % e)
for example in squad_dataset["validation"]:
    question = example["question"]
    context = example["context"]
    answers = example["answers"]

    # Use the QA pipeline to get an answer
    predicted_answer = qa_pipeline(question=question, context=context)
    # Calculate exact match (EM) and F1-score for this example
    em = int(predicted_answer["answer"].lower() == answers["text"][0].lower())
    f1 = 2 * (len(set(predicted_answer["answer"].lower().split()) & set(answers["text"][0].lower().split())) / (len(predicted_answer["answer"].lower().split()) + len(answers["text"][0].lower().split())))
    # Update total scores
    total_exact_match += em
    total_f1_score += f1
    iterator = iterator + 1
    if(iterator % 100 == 0):
      e = datetime.datetime.now()
      print("%s" % e)
      print(iterator)
      # Calculate average EM and F1 scores
      average_exact_match = total_exact_match / total_examples
      average_f1_score = total_f1_score / total_examples
      print(f"Average Exact Match (EM): {average_exact_match:.2%}")
      print(f"Average F1 Score: {average_f1_score:.2%}")

# Calculate average EM and F1 scores
average_exact_match = total_exact_match / total_examples
average_f1_score = total_f1_score / total_examples

print(f"Average Exact Match (EM): {average_exact_match:.2%}")
print(f"Average F1 Score: {average_f1_score:.2%}")
# Out:
# 2023-11-02 22:07:38.552111
# 2023-11-02 22:08:30.579520
# 100
# Average Exact Match (EM): 0.48%
# Average F1 Score: 0.65%
# 2023-11-02 22:09:22.706525
# 200
# Average Exact Match (EM): 1.16%
# Average F1 Score: 1.41%
# 2023-11-02 22:11:18.346355
# 300
# Average Exact Match (EM): 1.84%
# Average F1 Score: 2.17%
# 2023-11-02 22:12:03.927442
# 400
# Average Exact Match (EM): 2.46%
# Average F1 Score: 2.89%
# 2023-11-02 22:13:01.689983
# 500
# Average Exact Match (EM): 2.96%
# Average F1 Score: 3.60%
# 2023-11-02 22:13:54.345250
# 600
# Average Exact Match (EM): 3.46%
# Average F1 Score: 4.31%
# 2023-11-02 22:14:41.835462
# 700
# Average Exact Match (EM): 4.07%
# Average F1 Score: 5.00%
# 2023-11-02 22:16:00.581239
# 800
# Average Exact Match (EM): 4.58%
# Average F1 Score: 5.65%
# 2023-11-02 22:17:07.311366
# 900
# Average Exact Match (EM): 5.06%
# Average F1 Score: 6.38%
# 2023-11-02 22:18:22.225172
# 1000
# Average Exact Match (EM): 5.47%
# Average F1 Score: 7.05%
# 2023-11-02 22:19:37.254221
# 1100
# Average Exact Match (EM): 6.02%
# Average F1 Score: 7.75%
# 2023-11-02 22:20:30.116007
# 1200
# Average Exact Match (EM): 6.64%
# Average F1 Score: 8.50%
# 2023-11-02 22:21:25.300561
# 1300
# Average Exact Match (EM): 7.13%
# Average F1 Score: 9.21%
# 2023-11-02 22:22:27.353633
# 1400
# Average Exact Match (EM): 7.62%
